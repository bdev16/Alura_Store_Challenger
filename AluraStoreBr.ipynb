# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %%
loja2.head()
# Out:
#                  Produto   Categoria do Produto    Preço      Frete  \
# 0  Cadeira de escritório                 moveis   378.20  20.421138
# 1               Pandeiro  instrumentos musicais   102.37   3.035334
# 2              Cama king                 moveis   591.13  31.759020
# 3              Cama king                 moveis  1208.24  61.919584
# 4  Cadeira de escritório                 moveis   530.41  25.827176
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     04/08/2021    Thiago Silva              MG                    1
# 1     26/11/2020   Bianca Santos              RJ                    3
# 2     22/10/2021    Thiago Silva              SC                    5
# 3     04/05/2022   Larissa Alves              RS                    5
# 4     26/02/2022  Lucas Oliveira              SP                    4
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0            boleto                       1 -18.10 -44.38
# ...

# %%
loja3.head()
# Out:
#               Produto   Categoria do Produto    Preço      Frete  \
# 0  Secadora de roupas       eletrodomesticos  1713.50  88.823159
# 1              Cômoda                 moveis   386.81  18.180908
# 2              Violão  instrumentos musicais   404.62  23.197592
# 3       Bola de vôlei        esporte e lazer    78.40   4.463341
# 4       Guarda roupas                 moveis   694.76  34.578319
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     17/12/2021  Camila Ribeiro              CE                    4
# 1     10/02/2021   Larissa Alves              RS                    3
# 2     22/01/2023  Lucas Oliveira              SP                    5
# 3     22/03/2022     Pedro Gomes              BA                    4
# 4     12/01/2022   Bianca Santos              SP                    1
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       4  -5.20 -39.53
# ...

# %%
loja4.head()
# Out:
#                Produto Categoria do Produto    Preço      Frete  \
# 0          Lava louças     eletrodomesticos  1446.46  74.604083
# 1             Cama box               moveis   631.70  33.919251
# 2     Bola de basquete      esporte e lazer    31.54   0.000000
# 3  Modelagem preditiva               livros    76.93   1.680730
# 4       Fone de ouvido          eletronicos   185.14   7.442587
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     11/11/2022    Rafael Costa              SP                    4
# 1     03/01/2020    Thiago Silva              GO                    5
# 2     25/12/2022   Larissa Alves              MG                    5
# 3     23/11/2021  Lucas Oliveira              MG                    3
# 4     25/04/2022   Bianca Santos              SP                    4
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       3 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
def calcula_faturamento_loja(df_loja: pd.DataFrame) -> float:
  '''
  Vai realizar o calculo de faturamento de uma loja, pegando como base o DataFrame que contem seus dados.
  É necessário enviar um tipo dataframe por conta das instruções de conversão contidadas na função

  Retorno: O retorno da função vai ser um float com o valor do faturamento da loja
  '''
  df_modificado_loja = df_loja[['Produto', 'Preço', 'Frete']]

  dct_loja = {
      "Produtos": [],
      "Qtd_produtos": [],
      "Preço": [],
      "Frete": []
  }

  for produto, preco, frete in zip(df_modificado_loja['Produto'], df_modificado_loja['Preço'], df_modificado_loja['Frete']):
    if produto not in dct_loja['Produtos']:
        dct_loja["Produtos"].append(produto)
        dct_loja["Qtd_produtos"].append(1)
        dct_loja["Preço"].append(preco)
        dct_loja["Frete"].append(frete)
    else:
        indexProduto = dct_loja["Produtos"].index(produto)
        dct_loja["Qtd_produtos"][indexProduto] += 1

  faturamento_total_loja = 0;

  for quantidade, preco, frete in zip(dct_loja['Qtd_produtos'], dct_loja['Preço'], dct_loja['Frete']):
      faturamento_total_loja += (preco * quantidade) + frete

  return faturamento_total_loja

# %%
faturamento_loja = calcula_faturamento_loja(loja)
faturamento_loja2 = calcula_faturamento_loja(loja2)
faturamento_loja3 = calcula_faturamento_loja(loja3)
faturamento_loja4 = calcula_faturamento_loja(loja4)

faturamento_lojas = (('Loja 1', faturamento_loja), ('Loja 2', faturamento_loja2), ('Loja 3', faturamento_loja3), ('Loja 4', faturamento_loja4))

pd.DataFrame(faturamento_lojas, columns=['Lojas', 'Faturamento'])
# Out:
#     Lojas   Faturamento
# 0  Loja 1  1.535956e+06
# 1  Loja 2  1.519430e+06
# 2  Loja 3  1.480277e+06
# 3  Loja 4  1.310229e+06

# %%
lista_faturamento_lojas = [faturamento_loja, faturamento_loja2, faturamento_loja3, faturamento_loja4]

plt.figure(figsize=(8, 6))
barras = plt.bar(['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4'], lista_faturamento_lojas)
plt.xlabel('Lojas')
plt.ylabel('Faturamento Total')
# plt.ylim(0, 5)


# Adiciona os valores em cima de cada barra
for i, barra in enumerate(barras):
    altura = barra.get_height()
    valor_formatado = f'R$ {altura:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.')
    plt.text(barra.get_x() + barra.get_width() / 2, altura + (altura * 0.01),
             valor_formatado, ha='center', va='bottom', color='black', fontweight='normal', fontsize=7)

# %% [markdown]
# # 2. Vendas por Categoria

# %%
def calcula_faturamento_loja(df_loja: pd.DataFrame) -> pd.DataFrame:
  '''
  Vai realizar o calculo do faturamento da loja que vai ter seus dados informados, pegando como base o DataFrame que contem seus dados.
  É necessário enviar um tipo dataframe por conta das instruções de conversão contidadas na função

  Retorno: O retorno da função vai ser um dataframe
  '''
  df_modificado_loja = df_loja[['Categoria do Produto']]

  dct_loja = {
      "Categorias dos Produtos": [],
      "Qtd_vendas_categorias": []
  }

  for categoria in df_modificado_loja['Categoria do Produto']:
    if categoria not in dct_loja['Categorias dos Produtos']:
        dct_loja["Categorias dos Produtos"].append(categoria)
        dct_loja["Qtd_vendas_categorias"].append(1)
    else:
        indexCategoria = dct_loja["Categorias dos Produtos"].index(categoria)
        dct_loja["Qtd_vendas_categorias"][indexCategoria] += 1

  return pd.DataFrame(dct_loja)

# %%
Qtd_vendas_categoriasProduto_loja = calcula_faturamento_loja(loja)
Qtd_vendas_categoriasProduto_loja2 = calcula_faturamento_loja(loja2)
Qtd_vendas_categoriasProduto_loja3 = calcula_faturamento_loja(loja3)
Qtd_vendas_categoriasProduto_loja4 = calcula_faturamento_loja(loja4)

# %%
Qtd_vendas_categoriasProduto_loja
# Out:
#   Categorias dos Produtos  Qtd_vendas_categorias
# 0             eletronicos                    448
# 1                  moveis                    465
# 2              brinquedos                    324
# 3        eletrodomesticos                    312
# 4   utilidades domesticas                    171
# 5         esporte e lazer                    284
# 6                  livros                    173
# 7   instrumentos musicais                    182

# %%
Qtd_vendas_categoriasProduto_loja2
# Out:
#   Categorias dos Produtos  Qtd_vendas_categorias
# 0                  moveis                    442
# 1   instrumentos musicais                    224
# 2         esporte e lazer                    275
# 3             eletronicos                    422
# 4   utilidades domesticas                    181
# 5              brinquedos                    313
# 6        eletrodomesticos                    305
# 7                  livros                    197

# %%
Qtd_vendas_categoriasProduto_loja3
# Out:
#   Categorias dos Produtos  Qtd_vendas_categorias
# 0        eletrodomesticos                    278
# 1                  moveis                    499
# 2   instrumentos musicais                    177
# 3         esporte e lazer                    277
# 4             eletronicos                    451
# 5              brinquedos                    315
# 6   utilidades domesticas                    177
# 7                  livros                    185

# %%
Qtd_vendas_categoriasProduto_loja4
# Out:
#   Categorias dos Produtos  Qtd_vendas_categorias
# 0        eletrodomesticos                    254
# 1                  moveis                    480
# 2         esporte e lazer                    277
# 3                  livros                    187
# 4             eletronicos                    451
# 5   instrumentos musicais                    170
# 6              brinquedos                    338
# 7   utilidades domesticas                    201

# %%
df_vendas_categoria_produto_loja = calcula_faturamento_loja(loja)
qtd_vendas_categorias_loja = df_vendas_categoria_produto_loja['Qtd_vendas_categorias'].tolist()

df_vendas_categoria_produto_loja2 = calcula_faturamento_loja(loja2)
qtd_vendas_categorias_loja2 = df_vendas_categoria_produto_loja2['Qtd_vendas_categorias'].tolist()

df_vendas_categoria_produto_loja3 = calcula_faturamento_loja(loja3)
qtd_vendas_categorias_loja3 = df_vendas_categoria_produto_loja3['Qtd_vendas_categorias'].tolist()

df_vendas_categoria_produto_loja4 = calcula_faturamento_loja(loja4)
qtd_vendas_categorias_loja4 = df_vendas_categoria_produto_loja4['Qtd_vendas_categorias'].tolist()

nomes_categorias = df_vendas_categoria_produto_loja['Categorias dos Produtos'].tolist()

# Configuração do gráfico
plt.figure(figsize=(12, 6))

# Plotando com linhas e marcadores
plt.plot(nomes_categorias, qtd_vendas_categorias_loja, marker='o', label='Loja 1')
plt.plot(nomes_categorias, qtd_vendas_categorias_loja2, marker='o', label='Loja 2')
plt.plot(nomes_categorias, qtd_vendas_categorias_loja3, marker='o', label='Loja 3')
plt.plot(nomes_categorias, qtd_vendas_categorias_loja4, marker='o', label='Loja 4')

# Personalização
plt.xlabel('Categoria dos Produtos')
plt.ylabel('Quantidade de Vendas')
plt.title('Comparação de Vendas por Categoria entre Lojas (Gráfico de Linha)')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()

# %%
def retorna_string_qtd_categoria_loja(nome_loja: str, nome_categorias: list, qtd_vendas_categorias_loja: list) -> str:
  '''
  Vai criar uma string que vai conter todas as informações sobre a quantidade de vendas por categoria de produto de uma loja.

  Retorno: O retorno da função vai ser uma string completa
  '''
  stringCompleta = f'\n{nome_loja}'
  for nome, qtd_produto in zip(nomes_categorias, qtd_vendas_categorias_loja):
    stringCompleta += f'\n{nome}: {qtd_produto}'

  return stringCompleta

# %%
stringCompleta = retorna_string_qtd_categoria_loja('Loja 1', nomes_categorias, qtd_vendas_categorias_loja)
stringCompleta += '\n' + retorna_string_qtd_categoria_loja('Loja 2', nomes_categorias, qtd_vendas_categorias_loja2)
stringCompleta += '\n' + retorna_string_qtd_categoria_loja('Loja 3', nomes_categorias, qtd_vendas_categorias_loja3)
stringCompleta += '\n' + retorna_string_qtd_categoria_loja('Loja 4', nomes_categorias, qtd_vendas_categorias_loja4)

print(stringCompleta)
# Out:
# Loja 1
# eletronicos: 448
# moveis: 465
# brinquedos: 324
# eletrodomesticos: 312
# utilidades domesticas: 171
# esporte e lazer: 284
# livros: 173
# instrumentos musicais: 182
#
# Loja 2
# eletronicos: 442
# moveis: 224
# brinquedos: 275
# eletrodomesticos: 422
# utilidades domesticas: 181
# esporte e lazer: 313
# livros: 305
# instrumentos musicais: 197
#
# Loja 3
# eletronicos: 278
# moveis: 499
# brinquedos: 177
# eletrodomesticos: 277
# utilidades domesticas: 451
# esporte e lazer: 315
# livros: 177
# instrumentos musicais: 185
#
# Loja 4
# eletronicos: 254
# moveis: 480
# brinquedos: 277
# eletrodomesticos: 187
# utilidades domesticas: 451
# esporte e lazer: 170
# livros: 338
# instrumentos musicais: 201

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
def calcula_media_avaliacao_loja(df_loja: pd.DataFrame) -> float:
  '''
  Vai realizar o calculo da média de avaliação de uma loja, pegando como base o DataFrame que contem seus dados.
  É necessário enviar um tipo dataframe por conta das instruções de conversão contidadas na função

  Retorno: O retorno da função vai ser um float com a média
  '''

  avaliacao = df_loja['Avaliação da compra']
  total_notas = 0

  for nota in avaliacao:
    total_notas += nota

  media_avaliacao = total_notas / len(avaliacao)

  return media_avaliacao

# %%
media_avalicao_loja = calcula_media_avaliacao_loja(loja)
media_avalicao_loja2 = calcula_media_avaliacao_loja(loja2)
media_avalicao_loja3 = calcula_media_avaliacao_loja(loja3)
media_avalicao_loja4 = calcula_media_avaliacao_loja(loja4)

tp_media_avaliacao_lojas = (('Loja 1', media_avalicao_loja), ('Loja 2', media_avalicao_loja2), ('Loja 3', media_avalicao_loja3), ('Loja 4', media_avalicao_loja4))

pd.DataFrame(tp_media_avaliacao_lojas, columns=['Lojas', 'Média de Avaliação'])
# Out:
#     Lojas  Média de Avaliação
# 0  Loja 1            3.976685
# 1  Loja 2            4.037304
# 2  Loja 3            4.048326
# 3  Loja 4            3.995759

# %%
lista_media_avaliacao_lojas = [media_avalicao_loja, media_avalicao_loja2, media_avalicao_loja3, media_avalicao_loja4]

# Personalização
plt.figure(figsize=(8, 6))
barras = plt.bar(['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4'], lista_media_avaliacao_lojas)
plt.xlabel('Lojas')
plt.ylabel('Média de Avaliação')
plt.ylim(0, 5)


# Adiciona os valores em cima de cada barra
for i, barra in enumerate(barras):
    altura = barra.get_height()
    plt.text(barra.get_x() + barra.get_width() / 2, altura + 0.1, f'{altura:.2f}',
             ha='center', va='bottom')

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
def produtos_mais_vendidos(df_loja: pd.DataFrame) -> pd.DataFrame:
  '''
  Vai realizar o calculo para retornar os produtos mais vendidos de uma loja, pegando como base o DataFrame que contem seus dados.
  É necessário enviar um tipo dataframe por conta das instruções de conversão contidadas na função

  Retorno: O retorno da função vai ser um dataframe
  '''
  produtos = df_loja['Produto']
  dct_produtos = {
      "Produtos": [],
      "Qtd_vendas_produtos": []
  }

  for produto in produtos:
    if produto not in dct_produtos['Produtos']:
        dct_produtos["Produtos"].append(produto)
        dct_produtos["Qtd_vendas_produtos"].append(1)
    else:
        indexProduto = dct_produtos["Produtos"].index(produto)
        dct_produtos["Qtd_vendas_produtos"][indexProduto] += 1

  df_produtos = pd.DataFrame(dct_produtos)

  media_vendas_produtos = df_produtos['Qtd_vendas_produtos'].mean()
  produtos_mais_vendidos = df_produtos[df_produtos['Qtd_vendas_produtos'] >= media_vendas_produtos]
  produtos_mais_vendidos = produtos_mais_vendidos.sort_values(by='Qtd_vendas_produtos', ascending=True)

  return produtos_mais_vendidos.head(5)

def produtos_menos_vendidos(df_loja: pd.DataFrame) -> pd.DataFrame:

  produtos = df_loja['Produto']
  dct_produtos = {
      "Produtos": [],
      "Qtd_vendas_produtos": []
  }

  for produto in produtos:
    if produto not in dct_produtos['Produtos']:
        dct_produtos["Produtos"].append(produto)
        dct_produtos["Qtd_vendas_produtos"].append(1)
    else:
        indexProduto = dct_produtos["Produtos"].index(produto)
        dct_produtos["Qtd_vendas_produtos"][indexProduto] += 1

  df_produtos = pd.DataFrame(dct_produtos)

  media_vendas_produtos = df_produtos['Qtd_vendas_produtos'].mean()
  produtos_menos_vendidos = df_produtos[df_produtos['Qtd_vendas_produtos'] <= media_vendas_produtos]
  produtos_menos_vendidos = produtos_menos_vendidos.sort_values(by='Qtd_vendas_produtos', ascending=True)

  return produtos_menos_vendidos.head(5)

# %%
produtos_mais_vendidos(loja)
# Out:
#               Produtos  Qtd_vendas_produtos
# 8   Lavadora de roupas                   47
# 31            Guitarra                   47
# 7          Lava louças                   48
# 16   Xadrez de madeira                   49
# 38    Celular Plus X42                   49

# %%
produtos_menos_vendidos(loja)
# Out:
#              Produtos  Qtd_vendas_produtos
# 45       Celular ABXY                   33
# 41            Headset                   33
# 12  Panela de pressão                   35
# 50           Pandeiro                   36
# 39            Mochila                   39

# %%
df_produtos_mais_vendidos_loja1 = produtos_mais_vendidos(loja)
nomes_produtos_mais_vendidos_loja1 = df_produtos_mais_vendidos_loja1['Produtos'].tolist()
qtd_produtos_mais_vendidos_loja1 = df_produtos_mais_vendidos_loja1['Qtd_vendas_produtos'].tolist()

df_produtos_menos_vendidos_loja1 = produtos_menos_vendidos(loja)
nomes_produtos_menos_vendidos_loja1 = df_produtos_menos_vendidos_loja1['Produtos'].tolist()
qtd_produtos_menos_vendidos_loja1 = df_produtos_menos_vendidos_loja1['Qtd_vendas_produtos'].tolist()

fig, axs = plt.subplots(2, 1, figsize=(8, 10))

# Personalização
barras1 = axs[0].barh(nomes_produtos_mais_vendidos_loja1, qtd_produtos_mais_vendidos_loja1)
axs[0].set_title("Produtos mais vendidos")
axs[0].set_xlabel("Quantidade vendida")

# Adiciona os valores em cima de cada barra
for barra in barras1:
    largura = barra.get_width()
    y = barra.get_y() + barra.get_height() / 2
    axs[0].text(largura / 2, y, f'{largura:.2f}', ha='center', va='center', color='white', fontweight='bold')

barras2 = axs[1].barh(nomes_produtos_menos_vendidos_loja1, qtd_produtos_menos_vendidos_loja1)
axs[1].set_title("Produtos menos vendidos")
axs[1].set_xlabel("Quantidade vendida")

# Adiciona os valores em cima de cada barra
for barra in barras2:
    largura = barra.get_width()
    y = barra.get_y() + barra.get_height() / 2
    axs[1].text(largura / 2, y, f'{largura:.2f}', ha='center', va='center', color='white', fontweight='bold')

# %%
produtos_mais_vendidos(loja2)
# Out:
#                     Produtos  Qtd_vendas_produtos
# 20              Copo térmico                   47
# 39                  Cama box                   47
# 43  Carrinho controle remoto                   47
# 26                  Guitarra                   47
# 16               Boneca bebê                   48

# %%
produtos_menos_vendidos(loja2)
# Out:
#              Produtos  Qtd_vendas_produtos
# 9   Jogo de tabuleiro                   32
# 37     Mesa de jantar                   34
# 49         Impressora                   34
# 25           Poltrona                   35
# 44     Fone de ouvido                   37

# %%
df_produtos_mais_vendidos_loja2 = produtos_mais_vendidos(loja2)
nomes_produtos_mais_vendidos_loja2 = df_produtos_mais_vendidos_loja2['Produtos'].tolist()
qtd_produtos_mais_vendidos_loja2 = df_produtos_mais_vendidos_loja2['Qtd_vendas_produtos'].tolist()

df_produtos_menos_vendidos_loja2 = produtos_menos_vendidos(loja2)
nomes_produtos_menos_vendidos_loja2 = df_produtos_menos_vendidos_loja2['Produtos'].tolist()
qtd_produtos_menos_vendidos_loja2 = df_produtos_menos_vendidos_loja2['Qtd_vendas_produtos'].tolist()

fig, axs = plt.subplots(2, 1, figsize=(8, 10))

# Personalização
barras1 = axs[0].barh(nomes_produtos_mais_vendidos_loja2, qtd_produtos_mais_vendidos_loja2)
axs[0].set_title("Produtos mais vendidos")
axs[0].set_xlabel("Quantidade vendida")

# Adiciona os valores em cima de cada barra
for barra in barras1:
    largura = barra.get_width()
    y = barra.get_y() + barra.get_height() / 2
    axs[0].text(largura / 2, y, f'{largura:.2f}', ha='center', va='center', color='white', fontweight='bold')

barras2 = axs[1].barh(nomes_produtos_menos_vendidos_loja2, qtd_produtos_menos_vendidos_loja2)
axs[1].set_title("Produtos menos vendidos")
axs[1].set_xlabel("Quantidade vendida")

# Adiciona os valores em cima de cada barra
for barra in barras2:
    largura = barra.get_width()
    y = barra.get_y() + barra.get_height() / 2
    axs[1].text(largura / 2, y, f'{largura:.2f}', ha='center', va='center', color='white', fontweight='bold')

# %%
produtos_mais_vendidos(loja3)
# Out:
#              Produtos  Qtd_vendas_produtos
# 2              Violão                   47
# 14  Panela de pressão                   47
# 44           Poltrona                   47
# 33  Xadrez de madeira                   47
# 3       Bola de vôlei                   48

# %%
produtos_menos_vendidos(loja3)
# Out:
#             Produtos  Qtd_vendas_produtos
# 50  Blocos de montar                   35
# 12     Jogo de copos                   36
# 48       Micro-ondas                   36
# 29           Mochila                   36
# 46      Copo térmico                   38

# %%
df_produtos_mais_vendidos_loja3 = produtos_mais_vendidos(loja3)
nomes_produtos_mais_vendidos_loja3 = df_produtos_mais_vendidos_loja3['Produtos'].tolist()
qtd_produtos_mais_vendidos_loja3 = df_produtos_mais_vendidos_loja3['Qtd_vendas_produtos'].tolist()

df_produtos_menos_vendidos_loja3 = produtos_menos_vendidos(loja3)
nomes_produtos_menos_vendidos_loja3 = df_produtos_menos_vendidos_loja3['Produtos'].tolist()
qtd_produtos_menos_vendidos_loja3 = df_produtos_menos_vendidos_loja3['Qtd_vendas_produtos'].tolist()

fig, axs = plt.subplots(2, 1, figsize=(8, 10))

# Personalização
barras1 = axs[0].barh(nomes_produtos_mais_vendidos_loja3, qtd_produtos_mais_vendidos_loja3)
axs[0].set_title("Produtos mais vendidos")
axs[0].set_xlabel("Quantidade vendida")

# Adiciona os valores em cima de cada barra
for barra in barras1:
    largura = barra.get_width()
    y = barra.get_y() + barra.get_height() / 2
    axs[0].text(largura / 2, y, f'{largura:.2f}', ha='center', va='center', color='white', fontweight='bold')

barras2 = axs[1].barh(nomes_produtos_menos_vendidos_loja3, qtd_produtos_menos_vendidos_loja3)
axs[1].set_title("Produtos menos vendidos")
axs[1].set_xlabel("Quantidade vendida")

# Adiciona os valores em cima de cada barra
for barra in barras2:
    largura = barra.get_width()
    y = barra.get_y() + barra.get_height() / 2
    axs[1].text(largura / 2, y, f'{largura:.2f}', ha='center', va='center', color='white', fontweight='bold')

# %%
produtos_mais_vendidos(loja4)
# Out:
#            Produtos  Qtd_vendas_produtos
# 23   Dinossauro Rex                   47
# 19            Fogão                   47
# 48  Cubo mágico 8x8                   47
# 50    Sofá retrátil                   47
# 25     Copo térmico                   48

# %%
produtos_menos_vendidos(loja4)
# Out:
#                        Produtos  Qtd_vendas_produtos
# 6                      Guitarra                   33
# 36                Guarda roupas                   34
# 41                       Violão                   37
# 5                     Geladeira                   38
# 47  Ciência de dados com python                   38

# %%
df_produtos_mais_vendidos_loja4 = produtos_mais_vendidos(loja4)
nomes_produtos_mais_vendidos_loja4 = df_produtos_mais_vendidos_loja4['Produtos'].tolist()
qtd_produtos_mais_vendidos_loja4 = df_produtos_mais_vendidos_loja4['Qtd_vendas_produtos'].tolist()

df_produtos_menos_vendidos_loja4 = produtos_menos_vendidos(loja4)
nomes_produtos_menos_vendidos_loja4 = df_produtos_menos_vendidos_loja4['Produtos'].tolist()
qtd_produtos_menos_vendidos_loja4 = df_produtos_menos_vendidos_loja4['Qtd_vendas_produtos'].tolist()

fig, axs = plt.subplots(2, 1, figsize=(8, 10))

# Personalização
barras1 = axs[0].barh(nomes_produtos_mais_vendidos_loja4, qtd_produtos_mais_vendidos_loja4)
axs[0].set_title("Produtos mais vendidos")
axs[0].set_xlabel("Quantidade vendida")

# Adiciona os valores em cima de cada barra
for barra in barras1:
    largura = barra.get_width()
    y = barra.get_y() + barra.get_height() / 2
    axs[0].text(largura / 2, y, f'{largura:.2f}', ha='center', va='center', color='white', fontweight='bold')

barras2 = axs[1].barh(nomes_produtos_menos_vendidos_loja4, qtd_produtos_menos_vendidos_loja4)
axs[1].set_title("Produtos menos vendidos")
axs[1].set_xlabel("Quantidade vendida")

# Adiciona os valores em cima de cada barra
for barra in barras2:
    largura = barra.get_width()
    y = barra.get_y() + barra.get_height() / 2
    axs[1].text(largura / 2, y, f'{largura:.2f}', ha='center', va='center', color='white', fontweight='bold')

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
def calcula_frete_medio_loja(df_loja: pd.DataFrame) -> float:
  '''
  Vai realizar o calculo o frete médio de uma loja, pegando como base o DataFrame que contem seus dados.
  É necessário enviar um tipo dataframe por conta das instruções de conversão contidadas na função.

  Retorno: O retorno da função vai ser um dataframe
  '''
  frete = df_loja['Frete']
  total_frete = 0

  for valor in frete:
    total_frete += valor

  media_frete = total_frete / len(frete)

  return media_frete

# %%
media_valor_frete_loja1 = calcula_frete_medio_loja(loja)
media_valor_frete_loja2 = calcula_frete_medio_loja(loja2)
media_valor_frete_loja3 = calcula_frete_medio_loja(loja3)
media_valor_frete_loja4 = calcula_frete_medio_loja(loja4)

media_valor_frete_lojas = (('Loja 1', media_valor_frete_loja1), ('Loja 2', media_valor_frete_loja2), ('Loja 3', media_valor_frete_loja3), ('Loja4', media_avalicao_loja4))

pd.DataFrame(media_valor_frete_lojas, columns=['Lojas', 'Média do Valor do Frete'])
# Out:
#     Lojas  Média do Valor do Frete
# 0  Loja 1                34.691805
# 1  Loja 2                33.621941
# 2  Loja 3                33.074464
# 3   Loja4                 3.995759

# %%
lista_media_valor_frete_lojas = [media_valor_frete_loja1, media_valor_frete_loja2, media_valor_frete_loja3, media_valor_frete_loja4]

# Personalização
plt.figure(figsize=(8, 6))
barras = plt.barh(['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4'], lista_media_valor_frete_lojas)
plt.xlabel('Média de valor frete')
plt.ylabel('Lojas')
plt.title('Média de valor frete das lojas')

# Adiciona os valores em cima de cada barra
for barra in barras:
    largura = barra.get_width()
    y = barra.get_y() + barra.get_height() / 2
    plt.text(largura / 2, y, f'{largura:.2f}', ha='center', va='center', color='white', fontweight='bold')

plt.tight_layout()

# %% [markdown]
# # **Conclusão**
#
# Após análise dos dados de desempenho das quatro lojas do Sr. João, constatou-se que a **Loja 4 apresenta o pior faturamento**, com uma **diferença significativa de R$ 16.998,08 em relação à Loja 3, que é a segunda com menor faturamento**.
#
# Os principais produtos responsáveis pela geração de receita são os **eletrônicos** e os **móveis**. A Loja 4 apresenta uma performance desequilibrada nesses segmentos: enquanto tem boas vendas de móveis (480 unidades), possui baixo desempenho na venda de eletrônicos (254 unidades), um dos principais impulsionadores de faturamento. Em comparação, a Loja 2 vendeu 442 unidades de eletrônicos, mesmo com vendas menores de móveis (224 unidades).
#
# Além disso, **a Loja 4 mostra baixo volume de vendas em produtos estratégicos e menor diversidade nos itens mais vendidos**. O frete mais barato da loja pode atrair clientes, mas não tem sido suficiente para compensar a baixa performance em vendas de alto valor agregado.
#
# Diante desses fatores — **baixo faturamento, desempenho fraco em categorias chave e frete com pouco impacto positivo —, recomenda-se que o Sr. João considere vender a Loja 4,** pois ela representa o menor retorno financeiro entre as quatro unidades.
